# %%
# Visualizador de CSVs - Dados filtrados (PE)

import pandas as pd
from IPython.display import display

# %%
# Carregar todos os CSVs filtrados
df_planos_pe = pd.read_csv('../csv_with_filter/plano_acao_especial_PE.csv')
df_executores_pe = pd.read_csv('../csv_with_filter/executor_especial_PE.csv')
df_metas_pe = pd.read_csv('../csv_with_filter/meta_especial_PE.csv')
df_finalidades_pe = pd.read_csv('../csv_with_filter/finalidade_especial_PE.csv')
df_empenhos_pe = pd.read_csv('../csv_with_filter/empenho_especial_PE.csv')
df_documentos_pe = pd.read_csv('../csv_with_filter/documento_habil_especial_PE.csv')
df_ordens_pe = pd.read_csv('../csv_with_filter/ordem_pagamento_ordem_bancaria_especial_PE.csv')
df_historicos_pe = pd.read_csv('../csv_with_filter/historico_pagamento_especial_PE.csv')
df_planos_trabalho_pe = pd.read_csv('../csv_with_filter/plano_trabalho_especial_PE.csv')
df_relatorios_pe = pd.read_csv('../csv_with_filter/relatorio_gestao_especial_PE.csv')

# %%
# Visualizar as primeiras linhas de cada DataFrame
display(df_planos_pe.head())
display(df_executores_pe.head())
display(df_metas_pe.head())
display(df_finalidades_pe.head())
display(df_empenhos_pe.head())
display(df_documentos_pe.head())
display(df_ordens_pe.head())
display(df_historicos_pe.head())
display(df_planos_trabalho_pe.head())
display(df_relatorios_pe.head())
# Out:
#    id_plano_acao codigo_plano_acao  ano_plano_acao modalidade_plano_acao  \
# 0           3305       0903-003305            2020              Especial
# 1           3362       0903-003362            2020              Especial
# 2           3368       0903-003368            2020              Especial
# 3           3556       0903-003556            2020              Especial
# 4           3828       0903-003828            2020              Especial
#
#   situacao_plano_acao  cnpj_beneficiario_plano_acao  \
# 0              CIENTE                10091536000113
# 1              CIENTE                10132777000163
# 2              CIENTE                10150068000100
# 3              CIENTE                10296887000160
# 4              CIENTE                10168235000140
#
#   nome_beneficiario_plano_acao uf_beneficiario_plano_acao  \
# 0         MUNICIPIO DE CARUARU                         PE
# 1      MUNICIPIO DE CANHOTINHO                         PE
# ...

# %%
print("Linhas por DataFrame (completo):")
print("Planos:", len(df_planos_pe))
print("Executores:", len(df_executores_pe))
print("Metas:", len(df_metas_pe))
print("Finalidades:", len(df_finalidades_pe))
print("Empenhos:", len(df_empenhos_pe))
print("Documentos:", len(df_documentos_pe))
print("Ordens:", len(df_ordens_pe))
print("Históricos:", len(df_historicos_pe))
print("Planos Trabalho:", len(df_planos_trabalho_pe))
print("Relatórios:", len(df_relatorios_pe))
# Out:
# Linhas por DataFrame (completo):
# Planos: 9
# Executores: 0
# Metas: 0
# Finalidades: 0
# Empenhos: 16
# Documentos: 0
# Ordens: 0
# Históricos: 0
# Planos Trabalho: 0
# Relatórios: 1
